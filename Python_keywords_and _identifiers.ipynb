# %% [markdown]
# # Python Keywords and Identifiers

# %% [markdown]
#    [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-9z8jrahq/lab/tree/demo/Python_keywords_and%20_identifiers.ipynb)

# %% [markdown]
# - In this tutorial, you will learn about keywords (reserved words in Python) and identifiers (names given to variables, functions, etc.).

# %% [markdown]
# ##  Python is a case-sensitive language

# %% [markdown]
# ### 1. Python Keywords

# %% [markdown]
# - Keywords are the reserved words in Python.

# %% [markdown]
# - We cannot use a keyword as a variable name, function name or any other identifier. They are used to define the syntax and structure of the Python language.

# %% [markdown]
# - __In Python, keywords are case sensitive.__

# %% [markdown]
# - There are 33 keywords in Python 3.7. This number can vary slightly over the course of time.

# %% [markdown]
# - All the keywords except __True__, __False__ and __None__ are in lowercase and they must be written as they are.

# %% [markdown]
# - The list of all the keywords is given below.

# %% [markdown]
# - Complete list of keywords with their examples can be [Here](https://realpython.com/python-keywords/)

# %% [markdown]
# - and

# %% [markdown]
# - as

# %% [markdown]
# - assert

# %% [markdown]
# - async

# %% [markdown]
# - await

# %% [markdown]
# - break

# %% [markdown]
# - class

# %% [markdown]
# - continue

# %% [markdown]
# - def

# %% [markdown]
# - del

# %% [markdown]
# - elif

# %% [markdown]
# - else

# %% [markdown]
# - global

# %% [markdown]
# - if

# %% [markdown]
# - in

# %% [markdown]
# - __None__

# %% [markdown]
# - while

# %% [markdown]
# - with

# %% [markdown]
# - nonlocal

# %% [markdown]
# - yield

# %% [markdown]
# - not

# %% [markdown]
# - or

# %% [markdown]
# - pass

# %% [markdown]
# - lambda

# %% [markdown]
# - raise

# %% [markdown]
# - return

# %% [markdown]
# - try

# %% [markdown]
# - except

# %% [markdown]
# - __False__

# %% [markdown]
# - __True__

# %% [markdown]
# - finally

# %% [markdown]
# - for

# %% [markdown]
# - from

# %% [markdown]
# - import

# %% [markdown]
# ## 2. Python Identifiers

# %% [markdown]
# - An identifier is a name given to entities like class, functions, variables, etc.

# %% [markdown]
# - It helps to differentiate one entity from another.

# %% [markdown]
# ### 2.1 Rules for writing identifiers

# %% [markdown]
# 1. dentifiers can be a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore _. Names like __myClass, var_1__ and __print_this_to_screen__, all are valid example.

# %% [markdown]
# 2. An identifier cannot start with a digit. 1variable is invalid, but variable1 is a valid name.

# %% [markdown]
# 3. Keywords cannot be used as identifiers.

# %% [markdown]
# - global = 1 - invalid identifier

# %% [markdown]
# 4.  We cannot use special symbols like !, @, #, $, % etc. in our identifier.

# %% [markdown]
# - a@ = 0 - invalid identifier

# %% [markdown]
# - An identifier can be of any length.

# %% [markdown]
# ## 3. Conclusion

# %% [markdown]
# __Python is a case-sensitive language__. This means, Variable and variable are not the same.

# %% [markdown]
# - Always give the identifiers a name that makes sense. While c = 10 is a valid name, writing count = 10 would make more sense, and it would be easier to figure out what it represents when you look at your code after a long gap.

# %% [markdown]
# - Multiple words can be separated using an underscore, like this_is_a_long_variable.
