# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-9jdin7v9/lab/tree/demo/Python-data-types.ipynb)

# %% [markdown]
# # Python Data Types

# %% [markdown]
# In this tutorial, you will learn about different data types you can use in Python.

# %% [markdown]
# ## Data types in Python

# %% [markdown]
# - Every value in Python has a datatype.

# %% [markdown]
# - Since everything is an object in Python programming,

# %% [markdown]
#   -  data types are actually classes, and

# %% [markdown]
# - variables are instance (object) of these classes.

# %% [markdown]
# - There are various data types in Python. Some of the important types are listed below.

# %% [markdown]
# [1.Python Numners](https://www.programiz.com/python-programming/numbers)

# %% [markdown]
# [2.Python List](https://www.programiz.com/python-programming/list)

# %% [markdown]
# [3.Python Tuple](https://www.programiz.com/python-programming/tuple)

# %% [markdown]
# [4.Python Dictionary](https://www.programiz.com/python-programming/dictionary)

# %% [markdown]
# [5.Python Set](https://www.programiz.com/python-programming/set)

# %% [markdown]
# [6.Python Strings](https://www.programiz.com/python-programming/string)

# %% [markdown]
# ### [1.Python Numners](https://www.programiz.com/python-programming/numbers)

# %% [markdown]
# - Integers, floating point numbers and complex numbers fall under Python numbers category.

# %% [markdown]
# - They are defined as int, float and complex classes in Python.

# %% [markdown]
# - We can use the type() function to know which class a variable or a value belongs to.

# %% [markdown]
# - Similarly, the isinstance() function is used to check if an object belongs to a particular class.

# %%
a = 5
print(a, "is of type", type(a))

a = 2.0
print(a, "is of type", type(a))

a = 1+2j
print(a, "is complex number?", isinstance(1+2j,complex))
# Out:
# 5 is of type <class 'int'>
# 2.0 is of type <class 'float'>
# (1+2j) is complex number? True

# %% [markdown]
# - Integers can be of any length, it is only limited by the memory available.

# %% [markdown]
# - A floating-point number is accurate up to 15 decimal places. Integer and floating points are separated by decimal points. 1 is an integer, 1.0 is a floating-point number.

# %% [markdown]
# - Complex numbers are written in the form, x + yj, where x is the real part and y is the imaginary part.

# %% [markdown]
# - Here are some examples.

# %%
a = 1234567890123456789
a
# Out:
# 1234567890123456789

# %%
b = 0.1234567890123456789
b
# Out:
# 0.12345678901234568

# %% [markdown]
# - Notice that the float variable b got truncated.

# %%
c = 1+2j
c
# Out:
# (1+2j)

# %% [markdown]
# ### [2.Python List](https://www.programiz.com/python-programming/list)

# %% [markdown]
# - List is an ordered sequence of items. It is one of the most used datatype in Python and is very flexible. All the items in a list do not need to be of the same type.

# %% [markdown]
# - Declaring a list is pretty straight forward. Items separated by commas are enclosed within brackets [ ].

# %%
a = [1, 2.2, 'python']
a
# Out:
# [1, 2.2, 'python']

# %% [markdown]
# - We can use the slicing operator [ ] to extract an item or a range of items from a list.

# %% [markdown]
# - __The index starts from 0 in Python.__

# %%
a = [5,10,15,20,25,30,35,40]

# a[2] = 15
print("a[2] = ", a[2])

# a[0:3] = [5, 10, 15]
print("a[0:3] = ", a[0:3])

# a[5:] = [30, 35, 40]
print("a[5:] = ", a[5:])
# Out:
# a[2] =  15
# a[0:3] =  [5, 10, 15]
# a[5:] =  [30, 35, 40]

# %% [markdown]
# -
#
#     Lists are mutable, meaning, the value of elements of a list can be altered.

# %%
a = [1, 2, 3]
a[2] = 4
print(a)
# Out:
# [1, 2, 4]

# %% [markdown]
# ### [3.Python Tuple](https://www.programiz.com/python-programming/tuple)

# %% [markdown]
# - Tuple is an ordered sequence of items same as a list. The only difference is that tuples are immutable. Tuples once created cannot be modified.

# %% [markdown]
# - Tuples are used to write-protect data and are usually faster than lists as they cannot change dynamically.

# %% [markdown]
# - It is defined within parentheses () where items are separated by commas.

# %%
t = (5,'program', 1+3j)
type(t)
# Out:
# <class 'tuple'>

# %% [markdown]
# - We can use the slicing operator [] to extract items but we cannot change its value.

# %%
t = (5,'program', 1+3j)

# t[1] = 'program'
print("t[1] = ", t[1])

# t[0:3] = (5, 'program', (1+3j))
print("t[0:3] = ", t[0:3])

# Generates error
# Tuples are immutable
t[0] = 10
# Out:
# t[1] =  program
# t[0:3] =  (5, 'program', (1+3j))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# In  [9]:
# Line 11:    t[0] = 10
#
# TypeError: 'tuple' object does not support item assignment
# ---------------------------------------------------------------------------

# %% [markdown]
# ### [4.Python Dictionary](https://www.programiz.com/python-programming/dictionary)

# %% [markdown]
# - Dictionary is an unordered collection of key-value pairs.

# %% [markdown]
# - It is generally used when we have a huge amount of data. Dictionaries are optimized for retrieving data. We must know the key to retrieve the value.

# %% [markdown]
# - In Python, dictionaries are defined within braces {} with each item being a pair in the form key:value. Key and value can be of any type.

# %%
d = {1:'value','key':2}
type(d)
# Out:
# <class 'dict'>

# %% [markdown]
# - We use key to retrieve the respective value. But not the other way around.

# %%
d = {1:'value','key':2}
print(type(d))

print("d[1] = ", d[1]);

print("d['key'] = ", d['key']);

# Generates error
print("d[2] = ", d[2]);
# Out:
# <class 'dict'>
# d[1] =  value
# d['key'] =  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# In  [16]:
# Line 9:     print("d[2] = ", d[2]);
#
# KeyError: 2
# ---------------------------------------------------------------------------

# %% [markdown]
# ### [5.Python Set](https://www.programiz.com/python-programming/set)

# %% [markdown]
# - Set is an unordered collection of unique items.

# %% [markdown]
# - Set is defined by values separated by comma inside braces { }.

# %% [markdown]
# - Items in a set are not ordered.

# %%
a = {5,2,3,1,4}

# printing set variable
print("a = ", a)

# data type of variable a
print(type(a))
# Out:
# a =  {1, 2, 3, 4, 5}
# <class 'set'>

# %% [markdown]
# - We can perform set operations like union, intersection on two sets.

# %% [markdown]
# - __Sets have unique values. They eliminate duplicates.__

# %%
a = {1,2,2,3,3,3}
print(a)
# Out:
# {1, 2, 3}

# %% [markdown]
# - Since, set are unordered collection, indexing has no meaning. Hence, the slicing operator [] does not work.

# %%
a = {1,2,3}
a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# In  [14]:
# Line 2:     a[1]
#
# TypeError: 'set' object is not subscriptable
# ---------------------------------------------------------------------------

# %% [markdown]
# ### [6.Python Strings](https://www.programiz.com/python-programming/string)

# %% [markdown]
# - String is sequence of Unicode characters.

# %% [markdown]
# - We can use single quotes or double quotes to represent strings.

# %% [markdown]
# - Multi-line strings can be denoted using triple quotes, ''' or """.

# %%
s = "This is a string"
print(s)
# Out:
# This is a string

# %% [markdown]
# - Just like a list and tuple, the slicing operator [ ] can be used with strings.

# %% [markdown]
# - __Strings, however, are immutable.__

# %%
s = 'Hello world!'

# s[4] = 'o'
print("s[4] = ", s[4])

# s[6:11] = 'world'
print("s[6:11] = ", s[6:11])

# Generates error
# Strings are immutable in Python
s[5] ='d'
# Out:
# s[4] =  o
# s[6:11] =  world
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# In  [11]:
# Line 11:    s[5] ='d'
#
# TypeError: 'str' object does not support item assignment
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 7. Conversion between data types

# %% [markdown]
# - We can convert between different data types by using different type conversion functions like - int(), float(), str(), etc.

# %%
float(5)
# Out:
# 5.0

# %% [markdown]
# - Conversion from float to int will truncate the value (make it closer to zero).

# %%
int(10.6)
# Out:
# 10

# %%
int(-10.6)
# Out:
# -10

# %% [markdown]
# - Conversion to and from string must contain compatible values.

# %%
float('2.5')
# Out:
# 2.5

# %%
str('25')
# Out:
# '25'

# %%
int('1p')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# In  [22]:
# Line 1:     int('1p')
#
# ValueError: invalid literal for int() with base 10: '1p'
# ---------------------------------------------------------------------------

# %%
set([1,2,3])
# Out:
# {1, 2, 3}

# %%
tuple({5,6,7})
# Out:
# (5, 6, 7)

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# - To convert to dictionary, each element must be a pair:

# %%
dict([[1,2],[3,4]])
# Out:
# {1: 2, 3: 4}

# %%
dict([(3,26),(4,44)])
# Out:
# {3: 26, 4: 44}

# %% [markdown]
# https://www.programiz.com/python-programming/variables-datatypes
