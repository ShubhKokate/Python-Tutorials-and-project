# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-tpupbhf4/lab/tree/demo/Python_Dictionarys.ipynb)

# %% [markdown]
# # **Python Dictionaries**

# %% [markdown]
# ## **1. Dictionary**
#
# - A **dictionary** is a collection which is unordered, changeable and indexed.
#
# - In Python, dictionaries are written with curly brackets, and they have keys and values, called **Key-Value Pairs**.

# %%
#Example - Create and print a dictionary:

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# ## **2. Accessing Items**
#
# - You can access the items or values of a dictionary by referring to its key name, inside square brackets.

# %%
#Example - Get the value of the "brand" key.

x = thisdict["brand"]

x
# Out:
# 'Ford'

# %%
#Example - Get the value of the "model" key.

y = thisdict["model"]

y
# Out:
# 'Mustang'

# %%
#Example - Get the value of the "year" key.

z = thisdict["year"]

z
# Out:
# 1964

# %% [markdown]
# ### 2.1 **get() method**
#
#
# - There is also a method called **get()** that will give you the same result.

# %%
#Example - Get the value of the "brand" key.

x1 = thisdict.get("brand")

x1
# Out:
# 'Ford'
