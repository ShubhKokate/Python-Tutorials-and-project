# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-c27dcuvv/lab/tree/demo/Python_Conditions.ipynb)

# %% [markdown]
# # Python Conditions

# %% [markdown]
# ## 1. Python Conditions

# %% [markdown]
# Python supports the usual logical conditions from mathematics:

# %% [markdown]
# - Equals: a == b

# %% [markdown]
# - Not Equals: a != b

# %% [markdown]
# - Less than a<b

# %% [markdown]
# - Less than or equals to a<=b

# %% [markdown]
# - Greater than a>b

# %% [markdown]
# - Greater than or equals to a>=b

# %% [markdown]
# These conditions can be used in several ways, most commonly in "if statements" and loops.
