# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-9jdin7v9/lab/tree/demo/Python_Docstrings.ipynb)

# %% [markdown]
# # Python Docstrings

# %% [markdown]
# - In this tutorial, we will learn about Python docstrings. More specifically, we will learn how and why docstrings are used with the help of examples.

# %% [markdown]
# ## 1. Python Docstrings

# %% [markdown]
# - A docstring is short for __documentation string.__

# %% [markdown]
# - Python docstrings (documentation strings) are the string literals that appear right after the definition of a function, method, class, or module.

# %% [markdown]
# - Triple quotes are used while writing docstrings. For example:

# %%
def double(num):
  """Function to double the value"""
  return 2*num

# %% [markdown]
# - Docstrings appear right after the definition of a function, class, or a module. This separates docstrings from multiline comments using triple quotes.

# %% [markdown]
# - The docstrings are associated with the object as their doc attribute.

# %% [markdown]
# - So, we can access the docstrings of the above function with the following lines of code:

# %%
def double(num):
  """Function to double the value"""
  return 2*num

print(double.__doc__)
# Out:
# Function to double the value

# %% [markdown]
# ## Python docstrings

# %% [markdown]
# - By convention, the triple quotes that appear right after the function, method or class definition are docstrings (documentation strings).

# %% [markdown]
# - __Docstrings__ are associated with objects and can be accessed using the __doc__ attribute.

# %% [markdown]
# - Python docstrings are the string literals that appear right after the definition of a function, method, class or module.

# %% [markdown]
# - Let's take an example:

# %% [markdown]
# __Example 1: Docstrings__

# %%
def square(n):
  '''Takes in a number n, returns the square of n'''
  return n**2

# %% [markdown]
# - Here, the string literal:

# %% [markdown]
# - Takes in a number n, returns the square of n

# %% [markdown]
# - inside the triple quotation marks is the __docstring__ of the function square() as it appears right after its definition.

# %% [markdown]
# - __Note:__ We can also use triple ''' quotations to create docstrings.

# %% [markdown]
# - Python docstrings are strings used right after the definition of a function, method, class or module (like in Example 1). They are used to document our code.

# %% [markdown]
# - We can access these docstrings using the doc attribute.

# %% [markdown]
# ## 2. Python doc attribute

# %% [markdown]
# - Whenever string literals are present just after the definition of a function, module, class or a method, they are associated with the object as their doc attribute.

# %% [markdown]
# - We can later use this attribute to retrieve this docstring.

# %% [markdown]
# __Example 2: Printing docstring__

# %%
def square(n):
  '''Takes in a number n, returns the square of n'''
  return n**2


print(square.__doc__)
# Out:
# Takes in a number n, returns the square of n

# %% [markdown]
# - Here, the documentation of our square() function can be accessed using the doc attribute.

# %% [markdown]
# - Now, let's look at docstrings for the built-in function print():

# %% [markdown]
# __Example 3: Docstrings for the built-in print() function__

# %%
print(print.__doc__)
# Out:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.

# %% [markdown]
# - Here, we can see that the documentation of the print() function is present as the doc attribute of this function.

# %% [markdown]
# ## 3. Single-line docstrings in Python

# %% [markdown]
# - Single line docstrings are the documents that fit in one line

# %% [markdown]
# ### 3.1 Standard conventions to write single-line docstrings

# %% [markdown]
# - Even though they are single-lined, we still use the triple quotes around these docstrings as they can be expanded easily later.

# %% [markdown]
# - The closing quotes are on the same line as the opening quotes.

# %% [markdown]
# - There's no blank line either before or after the docstring.

# %% [markdown]
# - They should not be descriptive, rather they must follow "Do this, return that" structure ending with a period.

# %% [markdown]
# Let's take an example.

# %% [markdown]
# __Example 4: Write single-line docstrings for a function__

# %%
def multiplier(a, b):
  """Takes in two numbers, returns their product"""
  return a*b

# %% [markdown]
# ## 4. Multi-line Docstrings in Python

# %% [markdown]
# - Multi-line docstrings consist of a summary line just like a one-line docstring, followed by a blank line, followed by a more elaborate description.

# %% [markdown]
# - The PEP 257 document provides the standard conventions to write multi-line docstrings for various objects.

# %% [markdown]
# ## 5. Docstrings for Python Modules

# %% [markdown]
# - The docstrings for Python Modules should list all the available classes, functions, objects and exceptions that are imported when the module is imported.

# %% [markdown]
# - They should also have a one-line summary for each item.

# %% [markdown]
# - They are written at the beginning of the Python file.

# %% [markdown]
# - Let's look at the docstrings for the builtin module in Python called pickle.

# %% [markdown]
# __Example 5: Docstrings of Python module__

# %%
import pickle
print(pickle.__doc__)
# Out:
# Create portable serialized representations of Python objects.
#
# See module copyreg for a mechanism for registering custom picklers.
# See module pickletools source for extensive comments.
#
# Classes:
#
#     Pickler
#     Unpickler
#
# Functions:
#
#     dump(object, file)
#     dumps(object) -> string
#     load(file) -> object
#     loads(string) -> object
#
# Misc variables:
#
#     __version__
#     format_version
#     compatible_formats

# %% [markdown]
# - Here, we can see that the docstring written at the beginning of the pickle.py module file can be accessed as its docstring.

# %% [markdown]
# ## 6. Docstrings for Python Functions

# %% [markdown]
# - The docstring for a function or method should summarize its behavior and document its arguments and return values.

# %% [markdown]
# - It should also list all the exceptions that can be raised and other optional arguments.

# %% [markdown]
# __Example 6: Docstrings for Python functions__

# %%
def add_binary(a, b):
    '''

    Returns the sum of two decimal numbers in binary digits.

            Parameters:
                  a (int): A decimal integer
                  b (int): Another decimal integer
          
            Returns:
                  binary_sum(str): Binary string of the sum of a and b
    '''
    binary_sum = bin(a+b)[2:]
    return binary_sum


print(add_binary.__doc__)
# Out:
#     Returns the sum of two decimal numbers in binary digits.
#
#             Parameters:
#                   a (int): A decimal integer
#                   b (int): Another decimal integer
#
#             Returns:
#                   binary_sum(str): Binary string of the sum of a and b

# %% [markdown]
# - As you can see, we have included a short description of what the function does, the parameter it takes in and the value it returns.

# %% [markdown]
# - The string literal is embedded to the function __add_binary__ as its __doc__ attribute.

# %% [markdown]
# ## 7. Docstrings for Python Classes

# %% [markdown]
# - The docstrings for classes should summarize its behavior and list the public methods and instance variables.

# %% [markdown]
# - The subclasses, constructors, and methods should each have their own docstrings.

# %% [markdown]
# __Example 7: Docstrings for Python class__

# %% [markdown]
# - Suppose we have a Person.py file with the following code:

# %%
class Person:
    """
    A class to represent a person.

    ...

    Attributes
    ----------
    name : str
        first name of the person
    surname : str
        family name of the person
    age : int
        age of the person


    Methods
    -------
    info(additional=""):
        Prints the person's name and age.
    """
    

    def __init__(self, name, surname, age):
        """
        Constructs all the necessary attributes for the person object.

        Parameters
        ----------
            name : str
                first name of the person
            surname : str
                family name of the person
            age : int
                age of the person
        """

        self.name = name
        self.surname = surname
        self.age = age

    def info(self, additional=""):
        """
        Prints the person's name and age.

        If the argument 'additional' is passed, then it is appended after the main info.

        Parameters
        ----------
        additional : str, optional
            More info to be displayed (default is None)

        Returns
        -------
        None
        """

        print(f'My name is {self.name} {self.surname}. I am {self.age} years old.' + additional)

# %% [markdown]
# - Here, we can use the following code to access only the docstrings of the Person class:

# %%
print(Person.__doc__)
# Out:
#     A class to represent a person.
#
#     ...
#
#     Attributes
#     ----------
#     name : str
#         first name of the person
#     surname : str
#         family name of the person
#     age : int
#         age of the person
#
#
#     Methods
#     -------
#     info(additional=""):
#         Prints the person's name and age.

# %% [markdown]
# ## 8. Using the help() Function for Docstrings

# %% [markdown]
# - We can also use the __help()__ function to read the docstrings associated with various objects.

# %% [markdown]
# __Example 8: Read Docstrings with the help() function__

# %% [markdown]
# - We can use the help() function on the class Person in Example 7 as:

# %%
help(Person)
# Out:
# Help on class Person in module __main__:
#
# class Person(builtins.object)
#  |  Person(name, surname, age)
#  |
#  |  A class to represent a person.
#  |
#  |  ...
#  |
#  |  Attributes
#  |  ----------
#  |  name : str
#  |      first name of the person
#  |  surname : str
#  |      family name of the person
#  |  age : int
#  |      age of the person
#  |
#  |
#  |  Methods
#  |  -------
#  |  info(additional=""):
#  |      Prints the person's name and age.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, surname, age)
#  |      Constructs all the necessary attributes for the person object.
#  |
#  |      Parameters
#  |      ----------
#  |          name : str
#  |              first name of the person
#  |          surname : str
#  |              family name of the person
#  |          age : int
#  |              age of the person
#  |
#  |  info(self, additional='')
#  |      Prints the person's name and age.
#  |
#  |      If the argument 'additional' is passed, then it is appended after the main info.
#  |
#  |      Parameters
#  |      ----------
#  |      additional : str, optional
#  |          More info to be displayed (default is None)
#  |
#  |      Returns
#  |      -------
#  |      None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# - Here, we can see that the __help()__ function retrieves the docstrings of the Person class along with the methods associated with that class.

# %% [markdown]
# ## 9. Docstrings for Python Scripts

# %% [markdown]
# - The docstrings for Python script should document the script's functions and command-line syntax as a usable message.

# %% [markdown]
# - It should serve as a quick reference to all the functions and arguments.

# %% [markdown]
# ## 10. Docstrings for Python Packages

# %% [markdown]
# - The docstrings for a Python package is written in the package's init.py file.

# %% [markdown]
# - It should contain all the available modules and sub-packages exported by the package.

# %% [markdown]
# ## 11. Docstring Formats

# %% [markdown]
# - We can write docstring in many formats like the reStructured text (reST) format, Google format or the NumPy documentation format. To learn more, visit [Popular Docstring Formats](https://stackoverflow.com/questions/3898572/what-are-the-most-common-python-docstring-formats)

# %% [markdown]
# - We can also generate documentation from docstrings using tools like Sphinx. To learn more, visit Official Sphinx Documentation.
