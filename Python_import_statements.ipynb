# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-90fx6e2l/lab/workspaces/auto-9/tree/demo/Python_import_statements.ipynb)

# %% [markdown]
# # Python Import with import statement

# %% [markdown]
# - In this notebook, we will learn about Python modules and how to import them with import statement.

# %% [markdown]
# ## 1. Python Import

# %% [markdown]
# - When our program grows bigger, it is a good idea to break it into different modules.

# %% [markdown]
# - A module is a file containing Python definitions and statements.

# %% [markdown]
# - [Python modules](https://www.programiz.com/python-programming/modules) have a filename and end with the extension .py.

# %% [markdown]
# - Definitions inside a module can be imported to another module or the interactive interpreter in Python. We use the _import_ keyword to do this.

# %% [markdown]
# - For example, we can import the __math__ module by typing the following line:

# %%
import math

# %% [markdown]
# - We can use the module in the following ways:

# %% [markdown]
# import math
# print(math.pi)

# %% [markdown]
# - Now all the definitions inside __math__ module are available in our scope.

# %% [markdown]
# - We can also import some specific attributes and functions only, using the __from__ keyword.

# %% [markdown]
# - For Examaple:

# %%
from math import pi
pi
# Out:
# 3.141592653589793

# %% [markdown]
# - While importing a module, Python looks at several places defined in *sys.path*. It is a list of directory locations.

# %%
import sys
sys.path
# Out:
# ['/srv/conda/envs/notebook/lib/python37.zip', '/srv/conda/envs/notebook/lib/python3.7', '/srv/conda/envs/notebook/lib/python3.7/lib-dynload', '/srv/conda/envs/notebook/lib/python3.7/site-packages', '/srv/conda/envs/notebook/lib/python3.7/site-packages/locket-0.2.1-py3.7.egg', '.', '/srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/extensions']

# %% [markdown]
# - We can also add our own location to this list.

# %% [markdown]
# https://www.programiz.com/python-programming/input-output-import
