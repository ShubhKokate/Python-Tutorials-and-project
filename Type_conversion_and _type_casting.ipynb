# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-9jdin7v9/lab/workspaces/auto-y/tree/demo/Type_conversion_and%20_type_casting.ipynb)

# %% [markdown]
# # Python Type Conversion and Type Casting

# %% [markdown]
# - In this article, you will learn about the Type conversion and uses of type conversion.

# %% [markdown]
# - Before learning Type Conversion in Python, you should have knowledge about [Python Data Types](https://www.programiz.com/python-programming/variables-datatypes).

# %% [markdown]
# ##  Type Conversion

# %% [markdown]
# - The process of converting the value of one data type (integer, string, float, etc.) to another data type is called __type conversion__.

# %% [markdown]
# - Python has two types of type conversion.

# %% [markdown]
# 1. Implicit Type Conversion

# %% [markdown]
# 2. Explicit Type Conversion

# %% [markdown]
# ## 1.Implicit Type Conversion

# %% [markdown]
# - In Implicit type conversion, Python automatically converts one data type to another data type. This process doesn't need any user involvement.

# %% [markdown]
# - Let's see an example where Python promotes the conversion of the lower data type (integer) to the higher data type (float) to avoid data loss.

# %% [markdown]
# __Example 1: Converting integer to float__

# %%
num_int = 123
num_flo = 1.23

num_new = num_int + num_flo

print("datatype of num_int:",type(num_int))
print("datatype of num_flo:",type(num_flo))

print('\n')

print("Value of num_new:",num_new)
print("datatype of num_new:",type(num_new))
# Out:
# datatype of num_int: <class 'int'>
# datatype of num_flo: <class 'float'>
#
#
# Value of num_new: 124.23
# datatype of num_new: <class 'float'>

# %% [markdown]
# - We add two variables __num_int__ and __num_flo__, storing the value in num_new.

# %% [markdown]
# - We will look at the data type of all three objects respectively.

# %% [markdown]
# - In the output, we can see the __data type of num_int is an integer__ while the __data type of num_flo is a float__.

# %% [markdown]
# - Also, we can see the __num_new has a float data type__ because Python always converts smaller data types to larger data types to avoid the loss of data.

# %% [markdown]
# Now, let's try adding a string and an integer, and see how Python deals with it.

# %% [markdown]
# __Example 2: Addition of string(higher) data type and integer(lower) datatype__

# %%
num_int = 123
num_str = "456"

print("Data type of num_int:",type(num_int))
print("Data type of num_str:",type(num_str))
# Out:
# Data type of num_int: <class 'int'>
# Data type of num_str: <class 'str'>

# %% [markdown]
# __Now, we run the below command__

# %% [markdown]
# - print(num_int+num_str)

# %% [markdown]
# __We get the following output__

# %% [markdown]
# - TypeError Traceback (most recent call last)

# %% [markdown]
# - <ipython-input-6-9da633d766d2> in () ----> 1 print(num_int+num_str)

# %% [markdown]
# - TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# In the above progr

# %% [markdown]
# - We add two variables __num_int__ and __num_str__.

# %% [markdown]
# - As we can see from the output, we got TypeError. Python is not able to use Implicit Conversion in such conditions.

# %% [markdown]
# - However, Python has a solution for these types of situations which is known as Explicit Conversion.

# %% [markdown]
# ## 2.Explicit Type Conversion or Typecasting

# %% [markdown]
# - In Explicit Type Conversion, users convert the data type of an object to required data type. We use the predefined functions like int(), float(), str(), etc to perform explicit type conversion.

# %% [markdown]
# - This type of conversion is also called __typecasting__ because the user casts (changes) the data type of the objects.

# %% [markdown]
# - Syntax :

# %% [markdown]
#    required_datatype(expression)'

# %% [markdown]
# - __Typecasting__ can be done by assigning the required data type function to the expression.

# %% [markdown]
# For more information on typecasting, please visit [Type Conversion in Python](https://www.geeksforgeeks.org/type-conversion-python/).

# %% [markdown]
# __Example 3: Addition of string and integer using explicit conversion__

# %%
num_int = 123
num_str = "456"

print("Data type of num_int:",type(num_int))
print("Data type of num_str before Type Casting:",type(num_str))
# Out:
# Data type of num_int: <class 'int'>
# Data type of num_str before Type Casting: <class 'str'>

# %%
num_str = int(num_str)
print("Data type of num_str after Type Casting:",type(num_str))
# Out:
# Data type of num_str after Type Casting: <class 'int'>

# %%
num_sum = num_int + num_str

print("Sum of num_int and num_str:",num_sum)
print("Data type of the sum:",type(num_sum))
# Out:
# Sum of num_int and num_str: 579
# Data type of the sum: <class 'int'>

# %% [markdown]
# In the above program,

# %% [markdown]
# - We add __num_str__ and __num_int__ variable.

# %% [markdown]
# - We converted __num_str__ from string(higher) to integer(lower) type using __int() function__ to perform the addition.

# %% [markdown]
# - After converting __num_str__ to an integer value, Python is able to add these two variables.

# %% [markdown]
# - We got the __num_sum__ value and data type to be an integer.

# %% [markdown]
# ## 3. Key Points to Remember

# %% [markdown]
# -__Type Conversion__ is the conversion of object from one data type to another data type

# %% [markdown]
# - Implicit Type Conversion is automatically performed by the Python interpreter. Python avoids the loss of data in Implicit Type Conversion.

# %% [markdown]
# - __Explicit Type Conversion is also called Type Casting__, the data types of objects are converted using predefined functions by the user

# %% [markdown]
# - In Type Casting, loss of data may occur as we enforce the object to a specific data type.

# %% [markdown]
# For more information on typecasting, please visit [Type Conversion in Python](https://www.geeksforgeeks.org/type-conversion-python/).
