# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-90fx6e2l/lab/workspaces/auto-9/tree/demo/Python_Operators.ipynb)

# %% [markdown]
# # Python Operators

# %% [markdown]
# - In this tutorial, you'll learn everything about different types of operators in Python, their syntax and how to use them with examples.

# %% [markdown]
# ## 1. What are operators in python?

# %% [markdown]
# - __Operators__ are special symbols in Python that carry out arithmetic or logical computation.

# %% [markdown]
# - The value that the operator operates on is called the __operand__.

# %%
2 + 3
# Out:
# 5

# %% [markdown]
# Here,

# %% [markdown]
# - `+` is the `operator` that performs addition.

# %% [markdown]
# - `2` and `3` are the `operands` and

# %% [markdown]
# - `5` is the `output` of the operation.

# %% [markdown]
# ## 2. Arithmetic Operators

# %% [markdown]
# - Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication, etc.

# %% [markdown]
# - __Operator - Meaning - Example - (x = 15, y = 4)__

# %% [markdown]
# - `+` - `Add two operands or unary plus` - `(x + y = 19)`

# %% [markdown]
# - `-` - `Subtract right operand from the left or unary minus` - `(x - y = 11)`

# %% [markdown]
# - `*`- `Multiply two operands` - `(x * y = 60)`

# %% [markdown]
# - `/` - `Divide left operand by the right one (always results into float)` - `(x / y = 3.75)`

# %% [markdown]
# - `%` - `Modulus - remainder of the division of left operand by the right` - `(x % y = 3) (remainder of x/y)`

# %% [markdown]
# - `//` - `Floor division - division that results into whole number adjusted to the left in the number line` - `(x // y = 3)`

# %% [markdown]
# - `**` - `Exponent - left operand raised to the power of right` - `(x**y = 50625) (x to the power y)`

# %% [markdown]
# __Example 1: Arithmetic operators in Python__

# %%
x = 15
y = 4

# Output: x + y = 19
print('x + y =',x+y)

# Output: x - y = 11
print('x - y =',x-y)

# Output: x * y = 60
print('x * y =',x*y)

# Output: x / y = 3.75
print('x / y =',x/y)

# Output: x % y = 3
print('x % y =',x%y)

# Output: x // y = 3
print('x // y =',x//y)

# Output: x ** y = 50625
print('x ** y =',x**y)
# Out:
# x + y = 19
# x - y = 11
# x * y = 60
# x / y = 3.75
# x % y = 3
# x // y = 3
# x ** y = 50625

# %% [markdown]
# ## 3. Comparison (Relational) Operators

# %% [markdown]
# - Comparison operators are used to compare values.

# %% [markdown]
# - It returns either `True` or `False` according to the condition.

# %% [markdown]
# - __Operator - Meaning - Example - (x = 10, y = 12)__

# %% [markdown]
# - `>` - `Greater than - True if left operand is greater than the right` - `(x > y is False)`

# %% [markdown]
# - `<` - `Less than - True if left operand is less than the right` - `(x < y is True)`

# %% [markdown]
# - `==` - `Equal to - True if both operands are equal `- `(x == y is False)`

# %% [markdown]
# - `!=` - `Not equal to - True if operands are not equal` - `(x != y is True)`

# %% [markdown]
# - `>=` - `Greater than or equal to - True if left operand is greater than or equal to the right` - `(x >= y is False)`

# %% [markdown]
# - `<=` - `Less than or equal to - True if left operand is less than or equal to the right` - `(x <= y is True)`

# %% [markdown]
# __Example 2: Comparison operators in Python__

# %%
x = 10
y = 12

# Output: x > y is False
print('x > y is',x>y)

# Output: x < y is True
print('x < y is',x<y)

# Output: x == y is False
print('x == y is',x==y)

# Output: x != y is True
print('x != y is',x!=y)

# Output: x >= y is False
print('x >= y is',x>=y)

# Output: x <= y is True
print('x <= y is',x<=y)
# Out:
# x > y is False
# x < y is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %% [markdown]
# ## 4. Logical (Boolean) Operators

# %% [markdown]
# - Logical operators are the `and`, `or`, `not` operators.

# %% [markdown]
# - Here is the [truth table](https://www.programiz.com/python-programming/keyword-list#and_or_not) for these operators.

# %% [markdown]
# - __Operator - Meaning - Example - (x = True, y = False)__

# %% [markdown]
# - `and` - `True if both the operands are true` - `(x and y is False)`

# %% [markdown]
# - `or` - `True if either of the operands is true` -`(x or y is True)`

# %% [markdown]
# - `not` - `True if operand is false (complements the operand)` - `(not x is False)`

# %% [markdown]
# __Example 3: Logical Operators in Python__

# %%
x = True
y = False

print('x and y is',x and y)

print('x or y is',x or y)

print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %% [markdown]
# - Here is the [truth table](https://www.programiz.com/python-programming/keyword-list#and_or_not) for these operators.

# %% [markdown]
# ## 5. Bitwise Operators

# %% [markdown]
# - Bitwise operators act on operands as if they were strings of binary digits. They operate bit by bit, hence the name.

# %% [markdown]
# - For example, 2 is `10` in binary and 7 is `111`.

# %% [markdown]
# - __In the table below__: Let `x` = 10 (`0000 1010` in binary) and `y` = 4 (`0000 0100` in binary)

# %% [markdown]
# - __Operator - Meaning - Example__:

# %% [markdown]
# - `&` - `Bitwise AND `- `x & y = 0 (0000 0000)`

# %% [markdown]
# - `|` - `Bitwise OR` - `x | y = 14 (0000 1110)`

# %% [markdown]
# - `~` - `Bitwise NOT` - `~x = -11 (1111 0101)`

# %% [markdown]
# - `^` - `Bitwise XOR` - `x ^ y = 14 (0000 1110)`

# %% [markdown]
# - `>>` - `Bitwise right shift` - `x >> 2 = 2 (0000 0010)`

# %% [markdown]
# - `<<` - `Bitwise left shift` - `x << 2 = 40 (0010 1000)`

# %% [markdown]
# ## 6. Assignment Operators

# %% [markdown]
# - Assignment operators are used in Python to assign values to variables.

# %% [markdown]
# - `a = 5` is a simple assignment operator that assigns the value `5` on the right to the variable `a` on the left.

# %% [markdown]
# - There are various compound operators in Python like `a += 5` that adds to the variable and later assigns the same. It is equivalent to `a = a + 5`.

# %% [markdown]
# - __Operator - Example - Equivalent to__

# %% [markdown]
# - `=` - `x = 5` - `x = 5`

# %% [markdown]
# - `+=` - `x += 5` - `x = x + 5`

# %% [markdown]
# - `-=` - `x -= 5` - `x = x - 5`

# %% [markdown]
# - `*=` - `x *= 5` - `x = x * 5`

# %% [markdown]
# - `/=` - `x /= 5` - `x = x / 5`

# %% [markdown]
# - `%=` - `x %= 5` - `x = x % 5`

# %% [markdown]
# - `//=` - `x //= 5` - `x = x // 5`

# %% [markdown]
# - `**=` - `x **= 5` - `x = x ** 5`

# %% [markdown]
# - `&=` - `x &= 5` - `x = x & 5`

# %% [markdown]
# - `|=` - `x |= 5` - `x = x | 5`

# %% [markdown]
# - `^=` - `x ^= 5` - `x = x ^ 5`

# %% [markdown]
# - `>>=` - `x >>= 5` - `x = x >> 5`

# %% [markdown]
# - `<<=` - `x <<= 5` - `x = x << 5`

# %% [markdown]
# ## 7.Special Operators

# %% [markdown]
# Python language offers some special types of operators like th

# %% [markdown]
# - __identity operator__ ,or the

# %% [markdown]
# - __membership operator.__

# %% [markdown]
#
# They are described below with examples.

# %% [markdown]
# ### 7.1. Identity Operators

# %% [markdown]
# - There are two identity operators in Python. They are -

# %% [markdown]
# - ` is` and `is not` are the identity operators in python

# %% [markdown]
# - They are used to check if two values (or variables) are located on the same part of the memory.

# %% [markdown]
# - __Two variables that are equal does not imply that they are identical.__

# %% [markdown]
# - __Operator - Meaning - Example__

# %% [markdown]
# - `is` - `True if the operands are identical (refer to the same object)` - `x is True`

# %% [markdown]
# - `is not` - `True if the operands are not identical (do not refer to the same object)` - `x is not True`

# %% [markdown]
# __Example 4: Identity operators in Python__

# %%
x1 = 5
y1 = 5
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [1,2,3]

# Output: False
print(x1 is not y1)

# Output: True
print(x2 is y2)

# Output: False
print(x3 is y3)
# Out:
# False
# True
# False

# %% [markdown]
# - Here, we see that `x1` and `y1` are integers of the same values, so they are equal as well as identical. Same is the case with `x2` and `y2` (strings).

# %% [markdown]
# - But `x3` and `y3` are lists. They are equal but not identical. It is because the interpreter locates them separately in memory although they are equal.

# %% [markdown]
# ### 7.2. Membership Operators

# %% [markdown]
# - There are two membership operators in Python.

# %% [markdown]
# - `in` and `not in` are the membership operators in Python

# %% [markdown]
# - They are used to test whether a value or variable is found in a sequence (string, list, tuple, set and dictionary).

# %% [markdown]
# - __In a dictionary we can only test for presence of key, not the value.__

# %% [markdown]
# - __Operator - Meaning - Example__

# %% [markdown]
# - `in` - `True if value/variable is found in the sequence` - `5 in x`

# %% [markdown]
# - `not in` - `True if value/variable is not found in the sequence` - `5 not in x`

# %% [markdown]
# __Example #5: Membership operators in Python__

# %%
x = 'Hello world'
y = {1:'a',2:'b'}

# Output: True
print('H' in x)

# Output: True
print('hello' not in x)

# Output: True
print(1 in y)

# Output: False
print('a' in y)
# Out:
# True
# True
# True
# False

# %% [markdown]
# - Here, `'H'` is in `x` but `'hello'` is not present in `x` __ (remember, Python is case sensitive)__.

# %% [markdown]
# - Similarly, `1` is key and `'a'` is the value in dictionary `y`

# %% [markdown]
# - Hence, `'a'` in `y` returns `False`.

# %% [markdown]
# https://www.programiz.com/python-programming/operators
