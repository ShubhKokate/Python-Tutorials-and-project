# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://hub.gke2.mybinder.org/user/jupyterlab-jupyterlab-demo-9jdin7v9/lab/tree/demo/Variables_Constants_and_Literals.ipynb)

# %% [markdown]
# # Python Variables, Constants and Literals

# %% [markdown]
# - In this tutorial, you will learn about Python variables, constants, literals and their use cases.

# %% [markdown]
# ## 1. Variables

# %% [markdown]
# - A variable is a named location used to store data in the memory. It is helpful to think of variables as a container that holds data that can be changed later in the program.

# %% [markdown]
# - For example:

# %%
number = 10

# %% [markdown]
# Here, we have created a variable named number. We have assigned the value 10 to the variable.

# %% [markdown]
# You can think of variables as a bag to store books in it and that book can be replaced at any time.

# %%
number = 10
number = 1.1

# %% [markdown]
# - Initially, the value of number was 10. Later, it was changed to 1.1.

# %% [markdown]
# - __Note__: In Python, we don't actually assign values to the variables. Instead, Python gives the reference of the object(value) to the variable.

# %% [markdown]
# ### 1.1 Assigning values to Variables in Python

# %% [markdown]
# - As you can see from the above example, you can use the assignment operator = to assign a value to a variable.

# %% [markdown]
# __Example 1: Declaring and assigning value to a variable__

# %%
website = "apple.com"
print(website)
# Out:
# apple.com

# %% [markdown]
# - In the above program, we assigned a value apple.com to the variable website. Then, we printed out the value assigned to website i.e. apple.com

# %% [markdown]
# -__Note__: Python is a [type-inferred](https://en.wikipedia.org/wiki/Type_inference) language, so you don't have to explicitly define the variable type. It automatically knows that apple.com is a string and declares the website variable as a string.

# %% [markdown]
# __Example 2: Changing the value of a variable__

# %%
website = "apple.com"
print(website)

# assigning a new variable to website
website = "programiz.com"

print(website)
# Out:
# apple.com
# programiz.com

# %% [markdown]
# - In the above program, we have assigned apple.com to the website variable initially. Then, the value is changed to programiz.com.

# %% [markdown]
# __Example 3: Assigning multiple values to multiple variables__

# %%
a, b, c = 5, 3.2, "Hello"

print(a)
print(b)
print(c)
# Out:
# 5
# 3.2
# Hello

# %% [markdown]
# - If we want to assign the same value to multiple variables at once, we can do this as:

# %%
x = y = z = "same"

print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %% [markdown]
# - The second program assigns the same string to all the three variables x, y and z.

# %% [markdown]
# ## 2. Constants

# %% [markdown]
# - A constant is a type of variable whose value cannot be changed. It is helpful to think of constants as containers that hold information which cannot be changed later.

# %% [markdown]
# - You can think of constants as a bag to store some books which cannot be replaced once placed inside the bag.

# %% [markdown]
# ### 2.1 Assigning value to constant in Python

# %% [markdown]
# - In Python, constants are usually declared and assigned in a module. Here, the module is a new file containing variables, functions, etc which is imported to the main file.

# %% [markdown]
# - nside the module, constants are written in all capital letters and underscores separating the words.

# %% [markdown]
# __Example 4: Declaring and assigning value to a constant__

# %% [markdown]
# Create a __constant.py__:

# %% [markdown]
# - PI = 3.14

# %% [markdown]
# - GRAVITY = 9.8

# %% [markdown]
# ===========================================

# %% [markdown]
# Create a __main.py__:

# %% [markdown]
# - import constant

# %% [markdown]
# - print(constant.PI)

# %% [markdown]
# - print(constant.GRAVITY)

# %% [markdown]
# ===============================================

# %% [markdown]
# __Output__

# %% [markdown]
# - 3.14

# %% [markdown]
# - 9.8

# %% [markdown]
# ==================================================

# %% [markdown]
# __Explanation__

# %% [markdown]
# - In the above program, we create a constant.py module file. Then, we assign the constant value to PI and GRAVITY. After that, we create a main.py file and import the constant module. Finally, we print the constant value.

# %% [markdown]
# - __Note__: In reality, we don't use constants in Python. Naming them in all capital letters is a convention to separate them from variables, however, it does not actually prevent reassignment.

# %% [markdown]
# __Rules and Naming Convention for Variables and constants__

# %% [markdown]
# 1.Constant and variable names should have a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore (_). For example:

# %% [markdown]
# - snake_case

# %% [markdown]
# - MACRO_CASE

# %% [markdown]
# - camelCase

# %% [markdown]
# - CapWords

# %% [markdown]
# 2.Create a name that makes sense. For example, vowel makes more sense than v.

# %% [markdown]
# 3.If you want to create a variable name having two words, use underscore to separate them. For example:

# %% [markdown]
# - my_name

# %% [markdown]
# - current_salary

# %% [markdown]
# 4.Use capital letters possible to declare a constant. For example:

# %% [markdown]
# - PI

# %% [markdown]
# - G

# %% [markdown]
# - MASS

# %% [markdown]
# - SPEED_OF_LIGHT

# %% [markdown]
# - TEMP

# %% [markdown]
# 5.Never use special symbols like !, @, #, $, %, etc.

# %% [markdown]
# 6.Don't start a variable name with a digit.

# %% [markdown]
# ## 3. Literals

# %% [markdown]
# -
#     Literal is a raw data given in a variable or constant. In Python, there are various types of literals they are as follows:

# %% [markdown]
# ### 3.1 Numeric Literals

# %% [markdown]
# Numeric Literals are immutable (unchangeable).

# %% [markdown]
# Numeric literals can belong to 3 different numerical types:

# %% [markdown]
# - Integer

# %% [markdown]
# - Float and

# %% [markdown]
# - Complex

# %% [markdown]
# __Example 5: How to use Numeric literals in Python?__

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0
# 3.14j 3.14 0.0

# %% [markdown]
# In the above program,

# %% [markdown]
# - We assigned integer literals into different variables. Here, a is binary literal, b is a decimal literal, c is an octal literal and d is a hexadecimal literal.

# %% [markdown]
# - When we print the variables, all the literals are converted into decimal values.

# %% [markdown]
# - 10.5 and 1.5e2 are floating-point literals. 1.5e2 is expressed with exponential and is equivalent to 1.5 * 10 ^ 2.

# %% [markdown]
# -     We assigned a complex literal i.e 3.14j in variable x. Then we use imaginary literal (x.imag) and real literal (x.real) to create imaginary and real parts of complex numbers.

# %% [markdown]
# - To learn more about Numeric Literals, refer to [Python Numbers](https://www.programiz.com/python-programming/numbers).

# %% [markdown]
# ### 3.2 String Literals

# %% [markdown]
# - A string literal is a sequence of characters surrounded by quotes. We can use both single, double, or triple quotes for a string. And, a character literal is a single character surrounded by single or double quotes.

# %% [markdown]
# __Example 6: How to use string literals in Python?__

# %%
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\u00dcnic\u00f6de"
raw_str = r"raw \n string"

print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# C
# This is a multiline string with more than one line code.
# Ünicöde
# raw \n string

# %% [markdown]
# - In the above program, This is Python is a string literal and C is a character literal.

# %% [markdown]
# - The value in triple-quotes """ assigned to the multiline_str is a multi-line string literal.

# %% [markdown]
# - The string u"\u00dcnic\u00f6de" is a Unicode literal which supports characters other than English. In this case, \u00dc represents Ü and \u00f6 represents ö.

# %% [markdown]
# - r"raw \n string" is a raw string literal.

# %% [markdown]
# ### 3.3 Boolean literals

# %% [markdown]
# - A Boolean literal can have any of the two values: True or False.

# %%
x = (1 == True)
y = (1 == False)
a = True + 4
b = False + 10

print("x is", x)
print("y is", y)
print("a:", a)
print("b:", b)
# Out:
# x is True
# y is False
# a: 5
# b: 10

# %% [markdown]
# - n the above program, we use boolean literal True and False.

# %% [markdown]
# - n Python, __True represents the value as 1 and False as 0__.

# %% [markdown]
# - The value of x is True because 1 is equal to True. And, the value of y is False because 1 is not equal to False.

# %% [markdown]
# - Similarly, we can use the True and False in numeric expressions as the value. The value of a is 5 because we add True which has a value of 1 with 4. Similarly, b is 10 because we add the False having value of 0 with 10.

# %% [markdown]
# ### 3.4 Special literals

# %% [markdown]
# - Python contains one special literal i.e. None. We use it to specify that the field has not been created.

# %% [markdown]
# __Example 8: How to use special literals in Python?__

# %%
drink = "Available"
food = None

def menu(x):
    if x == drink:
        print(drink)
    else:
        print(food)

menu(drink)
menu(food)
# Out:
# Available
# None

# %% [markdown]
# n the above program, we define a menu function. Inside menu, when we set the argument as drink then, it displays Available. And, when the argument is food, it displays None.

# %% [markdown]
# ### 3.5 Literal Collections

# %% [markdown]
# here are four different literal collections

# %% [markdown]
# - List literals

# %% [markdown]
# - Tuple literals

# %% [markdown]
# - Dict literals, and

# %% [markdown]
# - Set literals

# %% [markdown]
# __Example 9: How to use literals collections in Python?__

# %%
fruits = ["apple", "mango", "orange"] #list
numbers = (1, 2, 3) #tuple
alphabets = {'a':'apple', 'b':'ball', 'c':'cat'} #dictionary
vowels = {'a', 'e', 'i' , 'o', 'u'} #set

print(fruits)
print(numbers)
print(alphabets)
print(vowels)
# Out:
# ['apple', 'mango', 'orange']
# (1, 2, 3)
# {'a': 'apple', 'b': 'ball', 'c': 'cat'}
# {'o', 'a', 'u', 'i', 'e'}

# %% [markdown]
# - n the above program, we created a list of fruits, a tuple of numbers, a dictionary dict having values with keys designated to each value and a set of vowels.

# %% [markdown]
# - To learn more about literal collections, refer to [Python Data Types](https://www.programiz.com/python-programming/variables-datatypes).
